# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
base = pd.read_csv("DADOS/Credit.csv")
base.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = base.iloc[:,0:20].values
classe = base.iloc[:,20].values

# %%
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:,3] = labelencoder.fit_transform(previsores[:,3])
previsores[:,5] = labelencoder.fit_transform(previsores[:,5])
previsores[:,6] = labelencoder.fit_transform(previsores[:,6])
previsores[:,8] = labelencoder.fit_transform(previsores[:,8])
previsores[:,9] = labelencoder.fit_transform(previsores[:,9])
previsores[:,11] = labelencoder.fit_transform(previsores[:,11])
previsores[:,13] = labelencoder.fit_transform(previsores[:,13])
previsores[:,14] = labelencoder.fit_transform(previsores[:,14])
previsores[:,16] = labelencoder.fit_transform(previsores[:,16])
previsores[:,18] = labelencoder.fit_transform(previsores[:,18])
previsores[:,19] = labelencoder.fit_transform(previsores[:,19])

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(previsores,
                                                       classe,
                                                       test_size = 0.3,
                                                       random_state = 0)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto\n",
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(x_treino, y_treino)
# Out:
# RandomForestClassifier()

# %%
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1334118056),
#  DecisionTreeClassifier(max_features='sqrt', random_state=578274592),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1912566029),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2072953022),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1915883177),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1454445481),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1252359950),
#  DecisionTreeClassifier(max_features='sqrt', random_state=332990214),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2041602539),
#  DecisionTreeClassifier(max_features='sqrt', random_state=112193107),
#  DecisionTreeClassifier(max_features='sqrt', random_state=434679546),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1583906431),
#  DecisionTreeClassifier(max_features='sqrt', random_state=6419078),
#  DecisionTreeClassifier(max_features='sqrt', random_state=469020794),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1980376622),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1274270896),
#  DecisionTreeClassifier(max_features='sqrt', random_state=204880511),
#  DecisionTreeClassifier(max_features='sqrt', random_state=863175984),
#  DecisionTreeClassifier(max_features='sqrt', random_state=26527288),
#  DecisionTreeClassifier(max_features='sqrt', random_state=294644890),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1566437730),
#  DecisionTreeClassifier(max_features='sqrt', random_state=805531007),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1293791085),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1661462401),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1732599447),
#  DecisionTreeClassifier(max_features='sqrt', random_state=528232564),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1115114762),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1298602415),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1994580382),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1912314567),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1033225504),
#  DecisionTreeClassifier(max_features='sqrt', random_state=932560114),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1723383472),
#  DecisionTreeClassifier(max_features='sqrt', random_state=852004577),
#  DecisionTreeClassifier(max_features='sqrt', random_state=171472297),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1323692180),
#  DecisionTreeClassifier(max_features='sqrt', random_state=778420678),
#  DecisionTreeClassifier(max_features='sqrt', random_state=376220212),
#  DecisionTreeClassifier(max_features='sqrt', random_state=429348155),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1498700720),
#  DecisionTreeClassifier(max_features='sqrt', random_state=386586231),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1001875808),
#  DecisionTreeClassifier(max_features='sqrt', random_state=66590845),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1941113526),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2042759643),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2109533965),
#  DecisionTreeClassifier(max_features='sqrt', random_state=393688458),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1823924920),
#  DecisionTreeClassifier(max_features='sqrt', random_state=409146426),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2075011345),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2005512368),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1657832552),
#  DecisionTreeClassifier(max_features='sqrt', random_state=619479737),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1923192007),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2095731254),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1216664651),
#  DecisionTreeClassifier(max_features='sqrt', random_state=543800724),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1053072673),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1901157933),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1900972502),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1685228650),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1828847876),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1871499706),
#  DecisionTreeClassifier(max_features='sqrt', random_state=910047888),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1501040667),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1043182900),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1775882206),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1021363800),
#  DecisionTreeClassifier(max_features='sqrt', random_state=296138206),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1687838306),
#  DecisionTreeClassifier(max_features='sqrt', random_state=620161057),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1933358856),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1305177858),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1580125794),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2029014265),
#  DecisionTreeClassifier(max_features='sqrt', random_state=110109469),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1036070449),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1649670232),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2063741605),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1834031513),
#  DecisionTreeClassifier(max_features='sqrt', random_state=681085194),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1654440609),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1998324950),
#  DecisionTreeClassifier(max_features='sqrt', random_state=90465094),
#  DecisionTreeClassifier(max_features='sqrt', random_state=938216667),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1512211573),
#  DecisionTreeClassifier(max_features='sqrt', random_state=750945803),
#  DecisionTreeClassifier(max_features='sqrt', random_state=584328852),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1698395339),
#  DecisionTreeClassifier(max_features='sqrt', random_state=210944741),
#  DecisionTreeClassifier(max_features='sqrt', random_state=725712695),
#  DecisionTreeClassifier(max_features='sqrt', random_state=368467578),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1697356820),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1485006492),
#  DecisionTreeClassifier(max_features='sqrt', random_state=818579190),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1941613614),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1696299362),
#  DecisionTreeClassifier(max_features='sqrt', random_state=391872159),
#  DecisionTreeClassifier(max_features='sqrt', random_state=487867492),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1998501917)]

# %%
previsoes = floresta.predict(x_teste)
previsoes
# Out:
# array(['bad', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'bad', 'good', 'good', 'bad', 'good', 'good',
#        'good', 'bad', 'good', 'good', 'good', 'good', 'good', 'good',
#        'bad', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'bad', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'bad',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'bad',
#        'good', 'bad', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'bad', 'bad', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'bad', 'good', 'good', 'bad', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'bad', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'bad',
#        'good', 'good', 'good', 'bad', 'bad', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'bad', 'bad', 'bad',
#        'good', 'good', 'good', 'bad', 'good', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'bad', 'bad', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'bad', 'bad', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'bad', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'bad', 'bad',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'bad', 'good',
#        'bad', 'bad'], dtype=object)

# %%
confusao = confusion_matrix(y_teste, previsoes)
confusao
# Out:
# array([[ 40,  46],
#        [ 16, 198]], dtype=int64)

# %%
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.7933333333333333

# %%
taxa_erro = 1 - taxa_acerto
taxa_erro
# Out:
# 0.20666666666666667
